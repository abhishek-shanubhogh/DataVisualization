# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2023-07-05 15:45:54--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 74.125.197.100, 74.125.197.102, 74.125.197.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.197.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/k1d3vra3cabnr42iae816pi9m7324iej/1688571900000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=3de009db-84fd-4ef5-a840-ba7c02b7251a [following]
# ...
# --2023-07-05 15:45:54--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/k1d3vra3cabnr42iae816pi9m7324iej/1688571900000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=3de009db-84fd-4ef5-a840-ba7c02b7251a
# ...

# %%
df = pd.read_csv("mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.info() #give all information about your data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# head and tail

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.head(-2)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1697     Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698     Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
#
# [1702 rows x 6 columns]

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %% [markdown]
# # How can we create a dataframe from scratch

# %%
     country	year	population	continent	life_exp	gdp_cap
0	Afghanistan	1952	8425333	Asia	28.801	779.445314
1	Afghanistan	1957	9240934	Asia	30.332	820.853030
2	Afghanistan	1962	102267083	Asia	31.997	853.100710

# %%
df2 = pd.DataFrame([['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314, 45],
              ['Afghanistan',1957, 9240934, 'Asia', 30.332, 820.853030],
              ['Afghanistan',1962, 102267083, 'Asia', 31.997, 853.100710]],
              columns = ['country','year','population','continent','life_exp','gdp_cap', "zdzf"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     3 non-null      object
#  1   year        3 non-null      int64
#  2   population  3 non-null      int64
#  3   continent   3 non-null      object
#  4   life_exp    3 non-null      float64
#  5   gdp_cap     3 non-null      float64
#  6   zdzf        1 non-null      float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 296.0+ bytes

# %%
pd.DataFrame({
          'country':['Afghanistan', 'Afghanistan'],
          'year':[1952,1957],
          'population':[842533, 9240934],
          'continent':['Asia', 'Asia'],
          'life_exp':[28.801, 30.332],
          'gdp_cap':[779.445314, 820.853030]
          })
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952      842533      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
type(df[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df[["country","life_exp"]]
# Out:
#           country  life_exp
# 0     Afghanistan    28.801
# 1     Afghanistan    30.332
# 2     Afghanistan    31.997
# 3     Afghanistan    34.020
# 4     Afghanistan    36.088
# ...           ...       ...
# 1699     Zimbabwe    62.351
# 1700     Zimbabwe    60.377
# 1701     Zimbabwe    46.809
# 1702     Zimbabwe    39.989
# 1703     Zimbabwe    43.487
#
# [1704 rows x 2 columns]

# %%
df[["country","life_exp"]].head()
# Out:
#        country  life_exp
# 0  Afghanistan    28.801
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088

# %%
# set(df["country"])

# %%
df["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df["country"].nunique()
# Out:
# 142

# %%
df["country"].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.rename({"country": "Country","population":"Population"}, axis=1)
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.rename({"country": "Country","population":"Population"}, axis=1, inplace=True)

# %%
df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.rename(columns = {"country":"Country"})
# Out:
#           Country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.drop("continent")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-238198bcf4af> in <cell line: 1>()
# ----> 1 df.drop("continent")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df.drop("continent", axis=1)
# Out:
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.drop(columns=["continent","life_exp"])
# Out:
#           country  year  population     gdp_cap
# 0     Afghanistan  1952     8425333  779.445314
# 1     Afghanistan  1957     9240934  820.853030
# 2     Afghanistan  1962    10267083  853.100710
# 3     Afghanistan  1967    11537966  836.197138
# 4     Afghanistan  1972    13079460  739.981106
# ...           ...   ...         ...         ...
# 1699     Zimbabwe  1987     9216418  706.157306
# 1700     Zimbabwe  1992    10704340  693.420786
# 1701     Zimbabwe  1997    11404948  792.449960
# 1702     Zimbabwe  2002    11926563  672.038623
# 1703     Zimbabwe  2007    12311143  469.709298
#
# [1704 rows x 4 columns]

# %%
#break and tryout
#10:07

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df["year+2"] =df["year"]+2

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap  year+2
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314    1954
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030    1959

# %%
df['gdp'] = df['gdp_cap'] * df['population']
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap  year+2  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314    1954
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030    1959
#
#             gdp
# 0  6.567086e+09
# 1  7.585449e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
#  6   year+2      1704 non-null   int64
#  7   gdp         1704 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 106.6+ KB

# %%
df["new_col"] = np.arange(1704) # this should be always size of your dataframe( rows in df)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  year+2  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314    1954
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030    1959
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710    1964
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138    1969
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106    1974
# ...           ...   ...         ...       ...       ...         ...     ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306    1989
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786    1994
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960    1999
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623    2004
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298    2009
#
#                gdp  new_col
# ...

# %%
df.drop(columns=["gdp","new_col","year+2"],inplace=True)

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
# list(range(2, df.shape[0]+2))

# %%
df.shape[0]
# Out:
# 1704

# %%
df.index = list(range(2, df.shape[0]+2))

# %%
df.index.values
# Out:
# array([   2,    3,    4, ..., 1703, 1704, 1705])

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 2     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1702     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1703     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1704     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1705     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.index[2]
# Out:
# 4

# %%
sample = df.head()

# %%
sample
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
sample.index = ["a","b","c","d","e"]

# %%
sample
# Out:
#        country  year  population continent  life_exp     gdp_cap
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
country = df["country"]

# %%
country
# Out:
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
#            ...
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# 1704       Zimbabwe
# 1705       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country[5:15]
# Out:
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13    Afghanistan
# 14        Albania
# 15        Albania
# 16        Albania
# Name: country, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
# Implicit  iloc
# Explicit  loc

# %%
df.loc[2]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 2, dtype: object

# %%
df.iloc[2]
# Out:
# country       Afghanistan
# year                 1962
# population       10267083
# continent            Asia
# life_exp           31.997
# gdp_cap         853.10071
# Name: 4, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[1:3]
# Out:
#        country  year  population continent  life_exp    gdp_cap
# 3  Afghanistan  1957     9240934      Asia    30.332  820.85303
# 4  Afghanistan  1962    10267083      Asia    31.997  853.10071

# %%
df.loc[2:4] # this will include my end index row also
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1702  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1703  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1704  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1705  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.iloc[-1]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1705, dtype: object

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
temp = df.set_index("country")

# %%
temp
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
temp.loc["Afghanistan"]
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# Afghanistan  1997    22227415      Asia    41.763  635.341351
# Afghanistan  2002    25268405      Asia    42.129  726.734055
# Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.reset_index()
# Out:
#       index      country  year  population continent  life_exp     gdp_cap
# 0         2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1         3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2         4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3         5  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4         6  Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...     ...          ...   ...         ...       ...       ...         ...
# 1699   1701     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700   1702     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   1703     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   1704     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   1705     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 7 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
new_row = {'country': 'India', 'year': 2000,'life_exp':37.08,'population':13500000,'gdp_cap':900.23}

# %%
df.append(new_row, ignore_index=True)
# Out:
# <ipython-input-144-85c282e4af20>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row, ignore_index=True)
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# ...

# %%
df.tail(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
len(df.index)
# Out:
# 1704

# %%
df.loc[len(df.index)] = ["India",2000,32242424,"Asia",43.34, 34345.344]

# %%
df
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332    820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997    853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020    836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088    739.981106
# ...           ...   ...         ...       ...       ...           ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377    693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809    792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989    672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487    469.709298
# 1704        India  2000    32242424      Asia    43.340  34345.344000
#
# [1705 rows x 6 columns]

# %%
df.loc[1804] = ["India",2000,32242424,"Asia",43.34, 34345.344]

# %%
df
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332    820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997    853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020    836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088    739.981106
# ...           ...   ...         ...       ...       ...           ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809    792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989    672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487    469.709298
# 1704        India  2000    32242424      Asia    43.340  34345.344000
# 1804        India  2000    32242424      Asia    43.340  34345.344000
#
# [1706 rows x 6 columns]

# %%
df.loc[1704] = ['India',2004 ,13500000,"Asia",37.08,900.23] # update old row

# %%
df
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332    820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997    853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020    836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088    739.981106
# ...           ...   ...         ...       ...       ...           ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809    792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989    672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487    469.709298
# 1704        India  2004    13500000      Asia    37.080    900.230000
# 1804        India  2000    32242424      Asia    43.340  34345.344000
#
# [1706 rows x 6 columns]

# %%
df.iloc[1705] = ['India',2504 ,13500000,"Asia",37.08,900.23] # update old row

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2504    13500000      Asia    37.080  900.230000
# 1804        India  2504    13500000      Asia    37.080  900.230000
#
# [1706 rows x 6 columns]

# %%
len(df.index)
# Out:
# 1706

# %%
df.iloc[len(df.index)-1] = ['India',2000 ,13500000,"Asia",37.08,900.23] # adding with iloc not possible

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.index = list(range(2, df.shape[0]+2))

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop(3, axis=0) # explicit index row to delete
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 2     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 4     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 7     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1703     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1704     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1705     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1706        India  2504    13500000      Asia    37.080  900.230000
# 1707        India  2000    13500000      Asia    37.080  900.230000
#
# [1705 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 6  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop([4,5,6], axis=0, inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 2     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 7     Afghanistan  1977    14880372      Asia    38.438  786.113360
# 8     Afghanistan  1982    12881816      Asia    39.854  978.011439
# 9     Afghanistan  1987    13867957      Asia    40.822  852.395945
# ...           ...   ...         ...       ...       ...         ...
# 1703     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1704     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1705     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1706        India  2504    13500000      Asia    37.080  900.230000
# 1707        India  2000    13500000      Asia    37.080  900.230000
#
# [1703 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 2     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 7     Afghanistan  1977    14880372      Asia    38.438  786.113360
# 8     Afghanistan  1982    12881816      Asia    39.854  978.011439
# 9     Afghanistan  1987    13867957      Asia    40.822  852.395945
# ...           ...   ...         ...       ...       ...         ...
# 1703     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1704     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1705     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1706        India  2504    13500000      Asia    37.080  900.230000
# 1707        India  2000    13500000      Asia    37.080  900.230000
#
# [1703 rows x 6 columns]

# %%
df.loc[1804] = ["India",2000,32242424,"Asia",43.34, 34345.344]

# %%
df
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 2     Afghanistan  1952     8425333      Asia    28.801    779.445314
# 3     Afghanistan  1957     9240934      Asia    30.332    820.853030
# 7     Afghanistan  1977    14880372      Asia    38.438    786.113360
# 8     Afghanistan  1982    12881816      Asia    39.854    978.011439
# 9     Afghanistan  1987    13867957      Asia    40.822    852.395945
# ...           ...   ...         ...       ...       ...           ...
# 1704     Zimbabwe  2002    11926563    Africa    39.989    672.038623
# 1705     Zimbabwe  2007    12311143    Africa    43.487    469.709298
# 1706        India  2504    13500000      Asia    37.080    900.230000
# 1707        India  2000    13500000      Asia    37.080    900.230000
# 1804        India  2000    32242424      Asia    43.340  34345.344000
#
# [1704 rows x 6 columns]

# %%
df.loc[1708] = ["India",2000,32242424,"Asia",43.34, 34345.344]

# %%
df
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 2     Afghanistan  1952     8425333      Asia    28.801    779.445314
# 3     Afghanistan  1957     9240934      Asia    30.332    820.853030
# 7     Afghanistan  1977    14880372      Asia    38.438    786.113360
# 8     Afghanistan  1982    12881816      Asia    39.854    978.011439
# 9     Afghanistan  1987    13867957      Asia    40.822    852.395945
# ...           ...   ...         ...       ...       ...           ...
# 1705     Zimbabwe  2007    12311143    Africa    43.487    469.709298
# 1706        India  2504    13500000      Asia    37.080    900.230000
# 1707        India  2000    13500000      Asia    37.080    900.230000
# 1804        India  2000    32242424      Asia    43.340  34345.344000
# 1708        India  2000    32242424      Asia    43.340  34345.344000
#
# [1705 rows x 6 columns]

# %%
df.loc["singhania"] = ["India",2000,32242424,"Asia",43.34, 34345.344]

# %%
df
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 2          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 3          Afghanistan  1957     9240934      Asia    30.332    820.853030
# 7          Afghanistan  1977    14880372      Asia    38.438    786.113360
# 8          Afghanistan  1982    12881816      Asia    39.854    978.011439
# 9          Afghanistan  1987    13867957      Asia    40.822    852.395945
# ...                ...   ...         ...       ...       ...           ...
# 1706             India  2504    13500000      Asia    37.080    900.230000
# 1707             India  2000    13500000      Asia    37.080    900.230000
# 1804             India  2000    32242424      Asia    43.340  34345.344000
# 1708             India  2000    32242424      Asia    43.340  34345.344000
# singhania        India  2000    32242424      Asia    43.340  34345.344000
#
# [1706 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 2  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 7  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 8  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 9  Afghanistan  1987    13867957      Asia    40.822  852.395945

# %%
df.drop(3, axis=0 )
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 2          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 7          Afghanistan  1977    14880372      Asia    38.438    786.113360
# 8          Afghanistan  1982    12881816      Asia    39.854    978.011439
# 9          Afghanistan  1987    13867957      Asia    40.822    852.395945
# 10         Afghanistan  1992    16317921      Asia    41.674    649.341395
# ...                ...   ...         ...       ...       ...           ...
# 1706             India  2504    13500000      Asia    37.080    900.230000
# 1707             India  2000    13500000      Asia    37.080    900.230000
# 1804             India  2000    32242424      Asia    43.340  34345.344000
# 1708             India  2000    32242424      Asia    43.340  34345.344000
# singhania        India  2000    32242424      Asia    43.340  34345.344000
#
# [1705 rows x 6 columns]

# %%
df.drop(3, axis=1 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-184-47ab5d47c738> in <cell line: 1>()
# ----> 1 df.drop(3, axis=1 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...
