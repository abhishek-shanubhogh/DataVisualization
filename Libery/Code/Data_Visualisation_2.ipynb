# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O vgsales.csv
# Out:
# --2023-07-17 16:04:32--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.164.115.154, 18.164.115.84, 18.164.115.106, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.164.115.154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2041483 (1.9M) [text/plain]
# Saving to: ‘vgsales.csv’
#
# vgsales.csv         100%[===================>]   1.95M  --.-KB/s    in 0.05s
#
# 2023-07-17 16:04:33 (37.7 MB/s) - ‘vgsales.csv’ saved [2041483/2041483]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16652.000000  16381.000000  16652.000000  16652.000000  16652.000000
# mean    8283.409620   2006.390513      2.752314      1.996875      2.499677
# std     4794.471477      5.863261      1.327002      1.322972      1.164023
# min        1.000000   1980.000000      0.140000      0.010000      0.000000
# 25%     4129.750000   2003.000000      1.781124      1.087977      1.781124
# 50%     8273.500000   2007.000000      2.697415      1.714664      2.480356
# 75%    12436.250000   2010.000000      3.677290      2.795123      3.176299
# max    16600.000000   2020.000000      8.725452      8.367985     12.722984
#
#         Other_Sales  Global_Sales
# count  16652.000000  16652.000000
# mean       1.151829      8.457873
# std        1.054813      3.717756
# min       -0.474276      0.240000
# 25%        0.394830      5.580341
# 50%        0.491870      7.536614
# 75%        1.781124     11.227334
# ...

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Continous- Continuous

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# how can I get global sales vary over the years
#
# Feature to feature correlation

# %%
data["Name"].value_counts()
# Out:
# Ice Hockey                                       41
# Baseball                                         17
# Need for Speed: Most Wanted                      12
# Ratatouille                                       9
# FIFA 14                                           9
#                                                  ..
# Indy 500                                          1
# Indy Racing 2000                                  1
# Indycar Series 2005                               1
# inFAMOUS                                          1
# Zyuden Sentai Kyoryuger: Game de Gaburincho!!     1
# Name: Name, Length: 11493, dtype: int64

# %%
ih = data.loc[data["Name"]=="Ice Hockey"]
ih.shape
ih
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...

# %%
sns.lineplot(x="Year", y="Global_Sales", data=ih)
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
sns.lineplot(x="Year", y="NA_Sales", data=ih)
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Ice Hockey Sales Trend for NA region")
sns.lineplot(x="Year", y="NA_Sales", data=ih)
plt.show()

# %%
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Ice Hockey Sales Trend for NA region")
sns.lineplot(x="Year", y="NA_Sales", data=ih, color="r")
plt.show()

# %%
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Ice Hockey Sales Trend for NA region")
plt.xlim(left=2000,right=2020)
sns.lineplot(x="Year", y="NA_Sales", data=ih, color="r")
plt.show()

# %%
baseball = data.loc[data['Name']=='Baseball']
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
sns.lineplot(x='Year', y='NA_Sales', data=ih)
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
sns.lineplot(x='Year', y='NA_Sales', data=baseball, label="Baseball")
sns.lineplot(x='Year', y='NA_Sales', data=ih, label="Ice Hockey")
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
sns.lineplot(x='Year', y='NA_Sales', data=ih, color ="r")
plt.legend(["Baseball","Ice Hockey"])
plt.show()

# %%
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
sns.lineplot(x='Year', y='NA_Sales', data=ih, color ="r")
plt.legend(["Baseball","Ice Hockey"], loc="lower left")
plt.show()

# %%
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
sns.lineplot(x='Year', y='NA_Sales', data=ih, color ="r")
plt.legend(["Baseball","Ice Hockey"], loc=(-0.5, 0.5))
plt.show()

# %%
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
sns.lineplot(x='Year', y='NA_Sales', data=ih, color ="r")
plt.legend(["Baseball","Ice Hockey"], loc="lower left", ncol=2, frameon=False)
plt.show()

# %%
print(max(ih["NA_Sales"]))
# Out:
# 0.9

# %%
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
sns.lineplot(x='Year', y='NA_Sales', data=ih)
plt.text(2003, max(ih["NA_Sales"]), "Maximum NA Sales Ice Hockey")
plt.legend(["Baseball","Ice Hockey"], loc="lower left")
plt.show()

# %%
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
sns.lineplot(x='Year', y='NA_Sales', data=ih)
plt.text(2003, max(ih["NA_Sales"]), "Maximum NA Sales Ice Hockey")
plt.legend(["Baseball","Ice Hockey"], loc="lower left")
plt.grid()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
data.head(2)
# Out:
#    Rank                          Name Platform    Year     Genre  Publisher  \
# 0  2061                          1942      NES  1985.0   Shooter     Capcom
# 1  9137  ¡Shin Chan Flipa en colores!       DS  2007.0  Platform  505 Games
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  4.569217  3.033887  3.439352     1.991671     12.802935
# 1  2.076955  1.493442  3.033887     0.394830      7.034163

# %% [markdown]
# Rank vs Global Sales

# %%
sns.lineplot(data=data, x="Rank", y="Global_Sales")
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
sns.scatterplot(data=data, x="Rank", y="Global_Sales")
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
+ ve correlation -> both are increasing or decreasing
-ve correlation -> when rank is increasing, sales is decreasing

# %% [markdown]
# # Categorical - Categorical

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
# get me the list of top 3 publishers names
["A","B","C"]

# %%
top3_pub = data['Publisher'].value_counts().index[:3]
top3_genre = data['Genre'].value_counts().index[:3]
top3_platform = data['Platform'].value_counts().index[:3]
top3_pub, top3_genre, top3_platform
# Out:
# (Index(['Electronic Arts', 'Activision', 'Namco Bandai Games'], dtype='object'),
#  Index(['Action', 'Sports', 'Misc'], dtype='object'),
#  Index(['DS', 'PS2', 'PS3'], dtype='object'))

# %%
# either of these providers and either of these genre and either of these platform

# %%
top3_data = data.loc[(data["Publisher"].isin(top3_pub)) & (data["Genre"].isin(top3_genre)) & (data["Platform"].isin(top3_platform))]
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# break for 7mins - 10:22

# %%
# distribution of genres for top-3 publishers
# which platform was used by top-3 publishers

# %%
sns.countplot(x="Publisher",data=top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %%
sns.countplot(x="Publisher",hue="Genre", data=top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %%
sns.countplot(x="Publisher",hue="Platform", data=top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/545/original/download_%281%29.png?1671006217)

# %% [markdown]
# ## Categorical - Continous

# %%
# average sales for each genre
# average sales for each platform
# average sales for each publishers

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x="Publisher", y="Global_Sales",data=top3_data)
plt.title('Sales for top3 publisher', fontsize=15)
# plt.grid()
plt.show()

# %%
sns.boxplot(x="Genre", y="Global_Sales",data=top3_data)
plt.title('Sales for top3 genre', fontsize=15)
# plt.grid()
plt.show()

# %%
sns.barplot(x="Genre", y="Global_Sales", data=top3_data, estimator=np.mean)
# Out:
# <Axes: xlabel='Genre', ylabel='Global_Sales'>

# %% [markdown]
# # Subplots

# %%
fig = plt.figure(figsize=(15,10))
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
fig.suptitle('Main title')
plt.show()

# %%
fig = plt.figure(figsize=(15,10))

plt.subplot(2,3,1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)

plt.subplot(2,3,3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color="r")

fig.suptitle('NU sales comparison')
# Out:
# Text(0.5, 0.98, 'NU sales comparison')

# %%
fig, axes = plt.subplots(2,2, figsize=(12,10))
axes[0,0].scatter(top3_data['NA_Sales'], top3_data['EU_Sales'])
axes[0,1].scatter(top3_data['NA_Sales'], top3_data['JP_Sales'])
axes[1,0].scatter(top3_data['NA_Sales'], top3_data['Other_Sales'])
axes[1,1].scatter(top3_data['NA_Sales'], top3_data['Global_Sales'])

# %%
plt.figure(figsize=(20,12)).suptitle("NA Sales vs regions",fontsize=20)


# Using a 2x3 subplot
plt.subplot(2, 2, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
plt.title('NA vs EU Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('EU', fontsize=12)

plt.subplot(2, 2, 2)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')
plt.title('NA vs JP Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('JP', fontsize=12)


plt.subplot(2, 2, 3)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')
plt.title('NA vs Other Region Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Other', fontsize=12)

plt.subplot(2, 2, 4)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')
plt.title('NA vs Global Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Global', fontsize=12)

plt.show()

# %%
plt.figure(figsize=(20,12)).suptitle("NA Sales vs regions",fontsize=20)


# Using a 2x3 subplot
plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
plt.title('NA vs EU Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('EU', fontsize=12)

plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')
plt.title('NA vs JP Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('JP', fontsize=12)


plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')
plt.title('NA vs Other Region Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Other', fontsize=12)

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')
plt.title('NA vs Global Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Global', fontsize=12)

plt.show()

# %%
plt.figure(figsize=(20,12)).suptitle("NA Sales vs regions",fontsize=20)


# Using a 2x3 subplot
plt.subplot(2, 3, 1) # rows, columns, position
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
plt.title('NA vs EU Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('EU', fontsize=12)

plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')
plt.title('NA vs JP Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('JP', fontsize=12)

# Countplot of publishers
plt.subplot(1,3,2)
sns.countplot(x='Publisher', data=top3_data)
plt.title('Count of games by each Publisher', fontsize=12)
plt.xlabel('Publisher', fontsize=12)
plt.ylabel('Count of games', fontsize=12)

plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')
plt.title('NA vs Other Region Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Other', fontsize=12)

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')
plt.title('NA vs Global Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Global', fontsize=12)

plt.show()
